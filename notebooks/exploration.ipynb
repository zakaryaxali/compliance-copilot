# %% [markdown]
# # compliance-copilot — exploration
#
# Scratch notebook for EDA on the source standards, prompt iteration for synthetic dataset generation, and qualitative spot-checks of model outputs.
